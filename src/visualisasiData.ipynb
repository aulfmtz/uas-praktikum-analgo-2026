# %%
import pandas as pd

print("Matriks Jarak CSV :")
print(pd.read_csv('C:/Users/Hosea DA/OneDrive/Documents/KULIAH/Semester 4/PRAKTIKUM/Analisis Algoritma/Projek UAS Analisis Algoritma/uas-praktikum-analgo-2026/data/matriks_jarak.csv'))
print("Berat Paket CSV :")
print(pd.read_csv('C:/Users/Hosea DA/OneDrive/Documents/KULIAH/Semester 4/PRAKTIKUM/Analisis Algoritma/Projek UAS Analisis Algoritma/uas-praktikum-analgo-2026/data/berat_paket.csv'))
print("Skenario Ekonomi CSV :")
print(pd.read_csv('C:/Users/Hosea DA/OneDrive/Documents/KULIAH/Semester 4/PRAKTIKUM/Analisis Algoritma/Projek UAS Analisis Algoritma/uas-praktikum-analgo-2026/data/skenario_ekonomi.csv'))
# Out:
# Matriks Jarak CSV :
#      Unnamed: 0  Hub  Customer 1 Customer 2  Customer 3  Customer 4  \
# 0           Hub  inf         5.0       inf          2.0         inf
# 1    Customer 1  5.0         inf          7         1.0         inf
# 2    Customer 2  inf         7.0        inf         inf         3.0
# 3    Customer 3  2.0         1.0        inf         inf         inf
# 4    Customer 4  inf         inf          3         inf         inf
# 5    Customer 5  inf         inf        inf         3.0         8.0
# 6    Customer 6  inf         inf        inf         inf         inf
# 7    Customer 7  inf         inf        inf         inf         6.0
# 8    Customer 8  inf         inf        inf         inf         inf
# 9    Customer 9  inf         inf        inf         inf         inf
# 10  Customer 10  inf         inf        inf         inf         inf
#
#     Customer 5  Customer 6  Customer 7  Customer 8  Customer 9  Customer 10
# ...
